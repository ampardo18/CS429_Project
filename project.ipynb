# %% [markdown]
# $\textbf{\underline{Part 1}}$

# %%
import os
import scrapy
from scrapy.crawler import CrawlerProcess
from urllib.parse import urlparse
import uuid
from threading import Thread

class Crawler(scrapy.Spider):
    name = "web_crawler"
    
    def __init__(self, seed_url, max_pages, max_depth, save_dir=None, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.start_urls = [seed_url]
        self.allowed_domains = ['en.wikipedia.org']
        self.max_pages = int(max_pages)
        self.pages_crawled = 0
        self.save_dir = save_dir or 'downloaded_pages'
        self.custom_settings = {
            'DEPTH_LIMIT': int(max_depth),
            'DOWNLOAD_DELAY': 1
        }

    def parse(self, response):
        if self.pages_crawled >= self.max_pages:
            return

        os.makedirs(self.save_dir, exist_ok=True)
        filename = f'{str(uuid.uuid4()).upper()}.html'
        filepath = os.path.join(self.save_dir, filename)
        with open(filepath, "wb") as f:
            f.write(response.body)
        self.pages_crawled += 1

        if self.pages_crawled >= self.max_pages:
            print("\n=======================")
            print(f"Total pages saved: {self.pages_crawled}")
            print("=======================\n")
            return
        
        for href in response.css('a::attr(href)').getall():
            if href and href.startswith('/wiki/') and not any(x in href for x in [':', '#']):
                yield response.follow(href, self.parse)
                
def run_crawler():
    crawl_process = CrawlerProcess()
    crawl_process.crawl(Crawler, seed_url='https://en.wikipedia.org/wiki/Main_Page', max_pages=10, max_depth=1, save_dir='downloaded_pages')
    crawl_process.start()
crawler_thread  = Thread(target=run_crawler)
crawler_thread.start()
# Out:
# 2025-12-07 15:30:02 [scrapy.utils.log] INFO: Scrapy 2.13.4 started (bot: scrapybot)
# 2025-12-07 15:30:02 [scrapy.utils.log] INFO: Versions:
# {'lxml': '6.0.2',
#  'libxml2': '2.11.9',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '25.5.0',
#  'Python': '3.12.4 (tags/v3.12.4:8e8a4ba, Jun  6 2024, 19:30:16) [MSC v.1940 '
#            '64 bit (AMD64)]',
#  'pyOpenSSL': '25.3.0 (OpenSSL 3.5.4 30 Sep 2025)',
#  'cryptography': '46.0.3',
#  'Platform': 'Windows-11-10.0.26200-SP0'}
# 2025-12-07 15:30:03 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-12-07 15:30:03 [asyncio] DEBUG: Using selector: SelectSelector
# 2025-12-07 15:30:03 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-12-07 15:30:03 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2025-12-07 15:30:03 [scrapy.extensions.telnet] INFO: Telnet Password: ea97ec2b49f95da6
# 2025-12-07 15:30:03 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2025-12-07 15:30:03 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2025-12-07 15:30:03 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-12-07 15:30:03 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.start.StartSpiderMiddleware',
#  'scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-12-07 15:30:03 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# While calling system event trigger handler
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\twisted\internet\base.py", line 518, in _continueFiring
#     callable(*args, **kwargs)
#   File "c:\Python312\Lib\site-packages\twisted\internet\base.py", line 951, in _reallyStartRunning
#     self._signals.install()
#   File "c:\Python312\Lib\site-packages\twisted\internet\_signals.py", line 150, in install
#     signal.signal(signal.SIGTERM, self._sigTerm)
#   File "c:\Python312\Lib\signal.py", line 58, in signal
#     handler = _signal.signal(_enum_to_int(signalnum), _enum_to_int(handler))
# builtins.ValueError: signal only works in main thread of the main interpreter
#
# 2025-12-07 15:30:03 [twisted] CRITICAL: While calling system event trigger handler
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\twisted\internet\base.py", line 518, in _continueFiring
#     callable(*args, **kwargs)
#   File "c:\Python312\Lib\site-packages\twisted\internet\base.py", line 951, in _reallyStartRunning
#     self._signals.install()
#   File "c:\Python312\Lib\site-packages\twisted\internet\_signals.py", line 150, in install
#     signal.signal(signal.SIGTERM, self._sigTerm)
#   File "c:\Python312\Lib\signal.py", line 58, in signal
#     handler = _signal.signal(_enum_to_int(signalnum), _enum_to_int(handler))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: signal only works in main thread of the main interpreter
# While calling system event trigger handler
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\twisted\internet\base.py", line 518, in _continueFiring
#     callable(*args, **kwargs)
#   File "c:\Python312\Lib\site-packages\scrapy\utils\ossignal.py", line 29, in install_shutdown_handlers
#     signal.signal(signal.SIGTERM, function)
#   File "c:\Python312\Lib\signal.py", line 58, in signal
#     handler = _signal.signal(_enum_to_int(signalnum), _enum_to_int(handler))
# builtins.ValueError: signal only works in main thread of the main interpreter
#
# 2025-12-07 15:30:03 [twisted] CRITICAL: While calling system event trigger handler
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\twisted\internet\base.py", line 518, in _continueFiring
#     callable(*args, **kwargs)
#   File "c:\Python312\Lib\site-packages\scrapy\utils\ossignal.py", line 29, in install_shutdown_handlers
#     signal.signal(signal.SIGTERM, function)
#   File "c:\Python312\Lib\signal.py", line 58, in signal
#     handler = _signal.signal(_enum_to_int(signalnum), _enum_to_int(handler))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: signal only works in main thread of the main interpreter
# 2025-12-07 15:30:03 [scrapy.core.engine] INFO: Spider opened
# 2025-12-07 15:30:03 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-12-07 15:30:03 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Main_Page> (referer: None)
# 2025-12-07 15:30:04 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://en.wikipedia.org/wiki/Main_Page> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Main_Page> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Charro> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/William_J._Fox> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Philip_J._Pierre> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/HMAS_Emu> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2025_Saint_Lucian_general_election> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Saint_Lucia_Labour_Party> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Tom_Stoppard> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/My_Time_at_Sandrock> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Asian_baby_girl> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Baltimore_classification> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Republic_Newspaper_Office> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/U.S._Route_66> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/House_of_Assembly_of_Saint_Lucia> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/United_States_twenty-dollar_bill> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/US_Treasury_specimen_book> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Ken_Selby> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Wikimedia_Foundation> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Bank_of_Indiana> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/United_States_Secretary_of_the_Treasury> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Hugh_McCulloch> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Bureau_of_Engraving_and_Printing> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Line_engraving> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Chester_A._Arthur> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Abraham_Lincoln> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/List_of_days_of_the_year> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Joseph_Cook> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Andrew_Johnson> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/December_8> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/December_6> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Nicholas_Hoult> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Theodor_Schwann> (referer: https://en.wikipedia.org/wiki/Main_Page)
# =======================
# Total pages saved: 10
# =======================
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Charles_Garnier_(missionary)> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2014_Midwest_FurFest_gas_attack> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Allen_Chastanet> (referer: https://en.wikipedia.org/wiki/2025_Saint_Lucian_general_election)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Broome,_Western_Australia> (referer: https://en.wikipedia.org/wiki/HMAS_Emu)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2021_Saint_Lucian_general_election> (referer: https://en.wikipedia.org/wiki/2025_Saint_Lucian_general_election)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Cairns> (referer: https://en.wikipedia.org/wiki/HMAS_Emu)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/TSS_Wahine> (referer: https://en.wikipedia.org/wiki/HMAS_Emu)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_the_United_Kingdom> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Glossary_of_motorsport_terms> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Environmentalism_in_motorsport> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Historic_motorsport> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_Portugal> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_the_United_States> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Deaths_in_motorsport> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_Russia> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_Italy> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_India> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_Latvia> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_Canada> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/ThrustSSC> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Supercars_Championship> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/List_of_vehicle_speed_records> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_Ireland> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_Greece> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_France> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_Germany> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/World_Rally-Raid_Championship> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_Finland> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Rally_raid> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/12-car_rally> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/European_Rally_Championship> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Baja_(cross-country_rally)> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Mud_bogging> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Green_laning> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Dune_bashing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Time_attack> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Autosolo> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Autoslalom> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Karting_World_Championship> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Formula_Three> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/European_Truck_Racing_Championship> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/European_Drag_Racing_Championship> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Autonomous_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Midget_car_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/World_Rallycross_Championship> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Sprint_car_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Pickup_truck_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Desert_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorsport_in_Australia> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Kart_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/GT_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Circuit_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Land_speed_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Cambridge_Advanced_Learner%27s_Dictionary> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Short_course_off-road_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Collins_Dictionary> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/FIA> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Ice_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Slot_car_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Radio-controlled_model> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/FIA_ecoRally_Cup> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Daily_Telegraph> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/F%C3%A9d%C3%A9ration_A%C3%A9ronautique_Internationale> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Union_Internationale_Motonautique> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorcycle_speedway> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Electric_motorsport> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/List_of_motorsport_championships> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Drone_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorcycle_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Air_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Freestyle_motocross> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Enduro> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Tractor_pulling> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorcycle_trials> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorboating> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Street_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorcycle_rally> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Monster_Jam> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Land_speed_record> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Demolition_derby> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Gymkhana_(motorcycle)> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Gymkhana_(motorsport)> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Autocross> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Drifting_(motorsport)> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/World_Rally_Championship> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Rock_crawling> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Regularity_rally> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Dakar_Rally> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Autoball> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Autotesting> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Motorkhana> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Special_stage_(rallying)> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Pacenotes> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Time_trial> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/European_Hill_Climb_Championship> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Pikes_Peak_International_Hill_Climb> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Goodwood_Festival_of_Speed> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Colorado> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Lawn_mower_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2010_Rally_Finland> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Toyota_Supra_in_motorsport> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Ford_Fiesta_S2000> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Rallycross> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Prescott_Speed_Hill_Climb> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Baja_1000> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Extreme_E> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Hillclimbing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Deutsche_Tourenwagen_Masters> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Karting> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Autograss> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/RAC_Rally> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Daytona_International_Speedway> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/SCORE_Stock_Mini> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Tractor_unit> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Rod_Hall_(racer)> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/FIA_World_Endurance_Championship> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Off-road_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Sports_prototype> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Truck_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2019_Indianapolis_500> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Sports_car> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Grand_tourer> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Felipe_Massa> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/H%C3%A9lio_Castroneves> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Mercedes-AMG_F1_W11_EQ_Performance> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Indianapolis_500> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Indianapolis_Motor_Speedway> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/IndyCar_Series> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Portland,_Oregon> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2019%E2%80%9320_Formula_E_Championship> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Indycar> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/One-design_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Silhouette_racing_car> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Electric_car> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/West_Indies_Federation> (referer: https://en.wikipedia.org/wiki/2025_Saint_Lucian_general_election)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Beijing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Formula_One_Group> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/GP3_Series> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Formula_E> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/GP2_Series> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Formula_4> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Formula_Ford> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Formula_Renault> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Formula_Two> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/1958_West_Indies_federal_elections> (referer: https://en.wikipedia.org/wiki/2025_Saint_Lucian_general_election)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Formula_Palmer_Audi> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Formula_One> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Board_track_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Formula_3> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Road_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Aspendale_Racecourse> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Street_circuit> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Oval_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/1931_Saint_Lucian_general_election> (referer: https://en.wikipedia.org/wiki/2025_Saint_Lucian_general_election)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/ISSN_(identifier)> (referer: https://en.wikipedia.org/wiki/2025_Saint_Lucian_general_election)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Moses_Jean_Baptiste> (referer: https://en.wikipedia.org/wiki/2025_Saint_Lucian_general_election)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/1928_Saint_Lucian_general_election> (referer: https://en.wikipedia.org/wiki/2025_Saint_Lucian_general_election)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/BMW_M4_DTM> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Jotham_Napat> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Yoweri_Museveni> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Keir_Starmer> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Vieux_Fort_Quarter> (referer: https://en.wikipedia.org/wiki/2025_Saint_Lucian_general_election)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Hakainde_Hichilema> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Faure_Gnassingb%C3%A9> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/%CA%BBAisake_Eke> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Samia_Suluhu_Hassan> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Kamla_Persad-Bissessar> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2004_NASCAR_Nextel_Cup_Series> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Cyril_Ramaphosa> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Jeremiah_Manele> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Lawrence_Wong> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Patrick_Herminie> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/1925_Saint_Lucian_general_election> (referer: https://en.wikipedia.org/wiki/2025_Saint_Lucian_general_election)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/James_Marape> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Paul_Kagame> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Formula_5000> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Bola_Tinubu> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Shehbaz_Sharif> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Anura_Kumara_Dissanayake> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Christopher_Luxon> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/David_Adeang> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Autodrome> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Daniel_Chapo> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Navin_Ramgoolam> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Robert_Abela> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Netumbo_Nandi-Ndaitwah> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Anwar_Ibrahim> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Sam_Matekane> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/William_Ruto> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Taneti_Maamau> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Andrew_Holness> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Irfaan_Ali> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Narendra_Modi> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/John_Mahama> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Peter_Mutharika> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Adama_Barrow> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Mohamed_Muizzu> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Brice_Oligui_Nguema> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Mark_Carney> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Paul_Biya> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/National_Off-Road_Racing_Association> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Auto_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/National_Auto_Sport_Association> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Russell_Dlamini> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/United_States_Auto_Club> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Banger_racing> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Sports_Car_Club_of_America> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/National_Hot_Rod_Association> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Stock_car_racing_in_the_United_Kingdom> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/NASCAR> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Nikos_Christodoulides> (referer: https://en.wikipedia.org/wiki/Philip_J._Pierre)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/IndyCar> (referer: https://en.wikipedia.org/wiki/Motorsport)
# 2025-12-07 15:30:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/IMSA> (referer: https://en.wikipedia.org/wiki/Motorsport)
# ...
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Charreada> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Haciendas> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Galician_language> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Royal_Australian_Air_Force> (referer: https://en.wikipedia.org/wiki/HMAS_Emu)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Mexican_rodeo> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Niceto_de_Zamacois> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Charro!> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Charo> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Midwest_FurFest> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Yokel> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Furry_convention> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Charro_(song)> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/STS-34> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2014> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Aguascalientes_City> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Charros_de_Jalisco> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Sombreros> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Space_Shuttle_Atlantis> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Galileo_(spacecraft)> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/1995> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Jupiter> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Trial_in_absentia> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Nuremberg_trials> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Berlin_Hauptbahnhof> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Martin_Bormann> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/1972> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Arkansas> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Battle_of_Prairie_Grove> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Confederate_States_of_America> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/1862> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/American_Civil_War> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Tiberius_II_Constantine> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Justin_II> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/574> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/National_Pearl_Harbor_Remembrance_Day> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Solidus_(coin)> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Ambrose> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/1941> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Calendar_of_saints> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/December_7> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Lorenz_Weinrich> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Said_Assagaff> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Elden_Campbell> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Ena_Collymore-Woodstock> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Caesar_(title)> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Yasser_Abu_Shabab> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Deaths_in_2025> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/El_Fasher_massacre> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Sudanese_civil_war_(2023%E2%80%93present)> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Timeline_of_the_Russo-Ukrainian_war_(1_September_2025_%E2%80%93_present)> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Timeline_of_the_Gaza_war_(3_October_2025_%E2%80%93_present)> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Gaza_genocide> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Gaza_war> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Russo-Ukrainian_war_(2022%E2%80%93present)> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Godwin_Friday> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2025_Vincentian_general_election> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Anicet_Ekane> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/New_Democratic_Party_(Saint_Vincent_and_the_Grenadines)> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Martin_P._Nilsson> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2025_World_Rally_Championship> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Vincent_Landais> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Daniela_Melchior> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Ring_of_Nestor> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/S%C3%A9bastien_Ogier> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Timeline_of_the_Sudanese_civil_war_(2025)> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Flag_of_Hong_Kong> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Gracie_Gold> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Raichu> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Maxim_Trankov> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Zachary_Donohue> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Jefferson_Davis> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Tatiana_Volosozhar> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Madison_Hubbell> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Shoma_Uno> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/November_2015_Paris_attacks> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Ice_dance> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2015%E2%80%9316_ISU_Grand_Prix_of_Figure_Skating> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Single_skating> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/International_Skating_Union> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Chamois> (referer: https://en.wikipedia.org/wiki/Charro)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Figure_skating_competition> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Encyclopedia> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2015_Troph%C3%A9e_%C3%89ric_Bompard> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Free_content> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/English_language> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Wikipedia> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Pair_skating> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Bordeaux> (referer: https://en.wikipedia.org/wiki/Main_Page)
# 2025-12-07 15:30:19 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-12-07 15:30:19 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 400396,
#  'downloader/request_count': 726,
#  'downloader/request_method_count/GET': 726,
#  'downloader/response_bytes': 43195007,
#  'downloader/response_count': 726,
#  'downloader/response_status_count/200': 726,
#  'dupefilter/filtered': 513,
#  'elapsed_time_seconds': 15.960042,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 12, 7, 21, 30, 19, 669609, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 234709391,
#  'httpcompression/response_count': 726,
#  'items_per_minute': 0.0,
#  'log_count/CRITICAL': 2,
#  'log_count/DEBUG': 730,
#  'log_count/INFO': 10,
#  'request_depth_max': 2,
#  'response_received_count': 726,
#  'responses_per_minute': 2904.0,
#  'scheduler/dequeued': 726,
#  'scheduler/dequeued/memory': 726,
#  'scheduler/enqueued': 726,
#  'scheduler/enqueued/memory': 726,
#  'start_time': datetime.datetime(2025, 12, 7, 21, 30, 3, 709567, tzinfo=datetime.timezone.utc)}
# 2025-12-07 15:30:19 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# $\textbf{\underline{Part 2.1}}$

# %%
from bs4 import BeautifulSoup
import re, os

def build_inverted_index(directory: str, output_json: str):
    inverted_index = {}
    documents = []
    document_ids = []

    for filename in os.listdir(directory):
        if not filename.endswith('.html'):
            continue
        doc_id = os.path.splitext(filename)[0]
        file_path = os.path.join(directory, filename)
        with open(file_path, 'r', errors='ignore') as f:
            html = f.read()

        soup = BeautifulSoup(html, 'lxml')
        text = soup.get_text(' ', strip=True)

        documents.append(text)
        document_ids.append(doc_id)

        tokens = re.findall(r"\b\w+\b", text.lower())
        for position, token in enumerate(tokens):
            if token not in inverted_index:
                inverted_index[token] = []
            if inverted_index[token] and inverted_index[token][-1][0] == doc_id:
                inverted_index[token][-1][1].append(position)
            else:
                inverted_index[token].append((doc_id, [position]))

    with open('index.json', 'w', encoding='utf-8') as f:
        f.write('index = {\n')
        items = list(inverted_index.items())
        for i, (token, entries) in enumerate(items):
            f.write(f'  "{token}": [\n')
            for j, (doc_id, positions) in enumerate(entries):
                doc_str = f"{doc_id}"
                pos_str = "[" + ", ".join(map(str, positions)) + "]"
                line = f"        ({doc_str}, {pos_str})"
                if j < len(entries) - 1:
                    line += ","
                f.write(line + "\n")

            if i < len(items) - 1:
                f.write('  ],\n')
            else:
                f.write('  ]\n')
        f.write('}\n')

    print(f"inverted index saved to {output_json}")

build_inverted_index('downloaded_pages', 'index.json')
# Out:
# inverted index saved to index.json

# %% [markdown]
# $\textbf{\underline{Part 2.2}}$

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def build_text(folder_name):
    documents = {}
    path = os.path.join(os.getcwd(), folder_name)
    for filename in os.listdir(path):
        if not filename.lower().endswith('.html'):
            continue
        doc_id = os.path.splitext(filename)[0]
        file_path = os.path.join(path, filename)
        with open(file_path, 'r', encoding='utf-8') as f:
            html = f.read()
        soup = BeautifulSoup(html, 'html.parser')
        for tag in soup(['script', 'style']):
            tag.decompose()
        text = soup.get_text(separator=' ')
        text = ' '.join(text.split())
        documents[doc_id] = text

    return documents

def search(query, documents):
    doc_ids = list(documents.keys())
    corpus = [documents[doc_id] for doc_id in doc_ids]

    vectorizer = TfidfVectorizer(token_pattern=r"(?u)\b\w+\b")
    tfidf_matrix = vectorizer.fit_transform(corpus)
    query_vector = vectorizer.transform([query])
    cosine_scores = cosine_similarity(query_vector, tfidf_matrix).flatten()

    results = []

    for idx, doc_id in enumerate(doc_ids):
        row = tfidf_matrix[idx].toarray()[0]

        tfidf_terms = {}
        for token in query.lower().split():
            if token in vectorizer.vocabulary_:
                term_index = vectorizer.vocabulary_[token]
                tfidf_weight = float(row[term_index])
            else:
                tfidf_weight = 0.0
            tfidf_terms[token] = tfidf_weight
        term_str = ", ".join([f"{term}: {value:.4f}" for term, value in tfidf_terms.items()])     
        results.append({
            'doc_id': doc_id,
            'cosine': float(cosine_scores[idx]),
            'tfidf_str': term_str
        })

    results.sort(key=lambda x: x["cosine"], reverse=True)

    return results


query = 'Computer science and mathematics'
documents = build_text('downloaded_pages')
result = search(query, documents)

for r in result[:6]:
    print(f'Document {r['doc_id']}: ')
    print(f'   Cosine Similarity Score: {r['cosine']:.4f}')
    print(f'   TF-IDF Weights: {r['tfidf_str']}\n')
# Out:
# Document BBA806C3-A4E9-475D-8BA2-98E8B07BAEEA:
#    Cosine Similarity Score: 0.1198
#    TF-IDF Weights: computer: 0.0000, science: 0.0048, and: 0.3324, mathematics: 0.0000
#
# Document 6FD3EC81-A68F-49D9-B166-C834D96C14EC:
#    Cosine Similarity Score: 0.0939
#    TF-IDF Weights: computer: 0.0000, science: 0.0000, and: 0.2709, mathematics: 0.0000
#
# Document 060FC781-87EC-4D81-B21A-49B9C6A12DBF:
#    Cosine Similarity Score: 0.0648
#    TF-IDF Weights: computer: 0.0000, science: 0.0000, and: 0.1869, mathematics: 0.0000
#
# Document 0D775518-51EE-402C-AAE1-A6D98E7EA115:
#    Cosine Similarity Score: 0.0623
#    TF-IDF Weights: computer: 0.0000, science: 0.0000, and: 0.1797, mathematics: 0.0000
#
# Document CBBA59F1-7CC3-4C68-A00E-EB3A04BC640D:
#    Cosine Similarity Score: 0.0623
#    TF-IDF Weights: computer: 0.0000, science: 0.0000, and: 0.1797, mathematics: 0.0000
#
# Document A8B429D5-8FF1-4CEC-AC5E-D3C4A5C9ABA0:
#    Cosine Similarity Score: 0.0620
#    TF-IDF Weights: computer: 0.0000, science: 0.0000, and: 0.1788, mathematics: 0.0000

# %% [markdown]
# $\textbf{\underline{Part 3}}$

# %%
import threading
from flask import Flask, request, send_file, jsonify
import pandas as pd
import io, os

import requests

documents = build_text('downloaded_pages')

app = Flask(__name__)


@app.route("/process", methods=["POST"])
def processor():
    try:
        if 'file' not in request.files:
            return jsonify({'error': 'No file was uploaded'}), 400
        
        filename = request.files['file']
        top_k = int(request.form.get('top_k', 3))

        try:
            df = pd.read_csv(filename, dtype=str)
        except Exception as error:
            return jsonify({'error': f'CSV read error: {str(error)}'}), 400
        required = {'query_id', 'query_text'}
        if not required.issubset(df.columns):
            return jsonify({'error': 'CSV must contain query_id and query_text'}), 400

        output_rows = []

        for _, row in df.iterrows():
            qid = row.get('query_id', '').strip()
            qtext = row.get('query_text', '').strip()
            if not qid:
                return jsonify({'error': 'query_id cannot be empty'}), 400
            if not qtext:
                return jsonify({"error": f"Empty query_text for query_id {qid}"}), 400
            try:
                ranked = search(qtext, documents)
            except Exception as e:
                return jsonify({
                    'error': f'Search failed for query_id {qid}: {str(e)}'}), 500
            for rank, item in enumerate(ranked[:top_k], start=1):
                output_rows.append({
                    'query_id': qid,
                    'rank': rank,
                    'document_id': item['doc_id']
                })
        out_df = pd.DataFrame(output_rows)

        out_buffer = io.StringIO()
        out_df.to_csv(out_buffer, index=False)
        out_buffer.seek(0)

        return send_file(
            io.BytesIO(out_buffer.getvalue().encode("utf-8")),
            mimetype="text/csv",
            as_attachment=True,
            download_name='results2.csv'
        )

    except Exception as fatal:
        return jsonify({'error': f'Unexpected server error: {str(fatal)}'}), 500


def run_app():
    app.run(port=5000)
thread = threading.Thread(target=run_app)
thread.start()

url = 'http://127.0.0.1:5000/process'
files = {'file': open('queries.csv', 'rb')}
data = {'top_k': 3}
response = requests.post(url, files=files, data=data)


if not response.ok:
    print('Error: ', response.text)
else:
    with open('results.csv', 'wb') as f:
        f.write(response.content)

    print(f'Output saved to results.csv with top-{data['top_k']} ranked retrieval')
# Out:
#  * Serving Flask app '__main__'
# 2025-12-07 14:05:18 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): 127.0.0.1:5000
#  * Debug mode: off
# 2025-12-07 14:05:18 [werkzeug] INFO: WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# 2025-12-07 14:05:18 [werkzeug] INFO: Press CTRL+C to quit
# 2025-12-07 14:05:18 [werkzeug] INFO: 127.0.0.1 - - [07/Dec/2025 14:05:18] "POST /process HTTP/1.1" 200 -
# 2025-12-07 14:05:18 [urllib3.connectionpool] DEBUG: http://127.0.0.1:5000 "POST /process HTTP/1.1" 200 1875
# Output saved to results.csv with top-3 ranked retrieval

# %% [markdown]
# $\textbf{\underline{Abstract}}$

# %% [markdown]
# $\text{This project includes three main parts: a web crawler, an inverted index builder and searching algorithm, and a processing algorithm for Top-K ranked retrieval. The development process}$
# $\text{involved an incremental approach, where each part of the project was developed and completed before moving on to the next part. Additionally, initial testing was also done before moving}$
# $\text{to other parts of the project to ensure a previously developed function works correctly. Once all parts were completed, more internal testing (not reflected on github repository) was done}$
# $\text{to ensure all parts worked correctly, especially with large inputs. Throughout the development process, dedicated days to debugging and understanding a part of the project were allocated}$
# $\text{to ensure a more smoother and efficient development.}$
#
# $\text{If more time were to be dedicaated to this project, the next steps in development would be adding query spelling-correction and suggestions, vector embedding representation, and distributed}$
# $\text{crawling. This would improve search accuracy by correcting typos and offering alternative terms, enable retrieval of contextually similar documents, and enhance scalability through large-scale,}$
# $\text{continuous updates to the web crawler.}$

# %% [markdown]
# $\textbf{\underline{Overview}}$

# %% [markdown]
# $\text{The solution outline is as follows:}$
#
# $\text{- Web Crawler - Used a scrapy crawler with CrawlerProcess; starts at a base URL and recursively follows links up to a specified depth and amount of .html files need}$
#
# $\text{- Indexer - Used BeautifulSoup to extract the text from the folder, tokenized each term within the folder, and built an positional inverted index as a .json file. The search} \\$
# $\text{algorithm calculates the cosine similarity and the TF-IDF weights of each term in comparison to the corpus for a specified query. } \\$
#
# $\text{- Processor - A Flask based processor with Top-K ranked retrieval that validates query text and query IDs within the queries.csv file and outputs a results.csv file containing} \\$
# $\text{query ID, rank, and document ID.}$
#
# $\text{Based on this solution outline, the following literatures were used to gain information about possible implementation methods:}$
#
# $\text{- [Scrapy Documentation](https://docs.scrapy.org/en/latest/topics/api.html): Used to learn about a scrapy crawler through CrawlerProcess. Provided useful} \\$
# $\text{information on relevant custom settings and functions that can be used tio create a web crawler.} \\$
#
# $\text{- [Flask Documentation](https://flask.palletsprojects.com/en/stable/api/): Used to learn about creating a Flask application and setting up a GET request for the project's processor} \\$
# $\text{algorithm. It also provided information on using send file to save a csv file into a user's directory.}$
#
# $\text{- [Sklearn Documentation](https://scikit-learn.org/stable/api/sklearn.html): Used to learn more about calculating TFIDF weights and cosine similarity scores.}$
#
# $\text{The system will use Scrapy based web crawler to gather html documents and store them in a folder. This folder will later be retrieved by a function that builds an} \\$
# $\text{posotional inverted index and stores the index in a json file. A query will be given to a search function that calculate its cosine similarity to each document and } \\ $
# $\text{TFIDF weights, relative to the corpus. These calculation will then be used to display Top-K ranked retrieved documents after each query ID and query text is processed} \\ $
# $\text{and error checked.}$

# %% [markdown]
# $\textbf{\underline{Design}}$

# %% [markdown]
# $\text{Based on a specified depth and max pages, the system will be able to scrap through a specific website and gather a set of html documents into a folder. The greater the depth specified, the}$
# $\text{deeper the crawler will go through each link found in each html document. Based on these results, the folder of html files is used to create a positional inverted index with document IDs,}$
# $\text{terms and positions in which each term exists in a document. Furthermore, the folder of html files is converted into a corpus with a python dictionary and used to build a search algorithm. This}$
# $\text{search algorithm accepts a query and calculates its cosine similarity and TF-IDF weights of each term within the query, relative to each document. These results are used within a processing algorithm}$
# $\text{that provides error checking and query validation, and Top-K ranked retrieval. This processing function uses the search algoirhtm on a queries.csv file, which contains query text and query IDs and}$
# $\text{provides the Top-K ranked retrieval results through a results.csv file containing document IDs, query IDs, and ranks for each document.}$
#
# $\text{The following diagram was created to showcase the interactions between each project component:}$
# ![Interactions Diagram](images/interactions.png)

# %% [markdown]
# $\text{In terms of integration, the web crawler goes through a specified website with a user determined depth and max pages, and stores the result in a folder. Within}$
# $\text{the folder, it contains .html files that were scrapped from the specified website. This document folder is then used to build the positional inverted index}$
# $\text{to show the positions of each term in the documents and their respective positions. The same document folder is built as a corpus using a python dictionary}$
# $\text{for the basis of the search and processor algorithms. A valid query text and query ID are expected from the user through a csv file, with proper text validations}$
# $\text{and error checking before the search algorithm is used on each query. Once the search algorithm is called, it uses the previously built corpus to }$
# $\text{calculate the cosine similarity of the query and TF-IDF weights of each term in the query, relative to each document. Based on these results, the processor algorithm}$
# $\text{will output a specified Top-K ranked retrieval (predetermined to be 4) as a csv file.}$

# %% [markdown]
# $\textbf{\underline{Architecture}}$

# %% [markdown]
# $\text{The software components  of this project are the following: }$
#
# $\text{- Scarpy based Web Crawler}$
#
# $\text{- Positional Inverted Index Builder, corpus builder and search algorithm}$
#
# $\text{- Processor algorithm with error checking and query validation, with Top-K ranked retrieval}$
#
# $\text{The following diagram was created to explain the communication }$
#
# ![Interface Diagram](images/interfaces.png)

# %% [markdown]
# $\text{The web crawler was built using the CrawlerProcess library, with custom settings for depth limit and a one-second download delay. These settings}$
# $\text{were applied to adhere to the safe crawling rules that wikipedia has in place, while also preserving the speed of the crawler. Within}$
# $\text{the constructor of the Crawler class, a seed\_url, maximum depth, maximum pages, and a directory are provided by the user. In addition, the constructor}$
# $\text{sets the base domain to "en.wikipedia.org." This is done to avoid the crawler going into wikipedia pages that contain another language. With the name}$
# $\text{of the new directory is given, the OS library was used to create a new folder that would store the results from the web crawler as .html files.}$
# $\text{The UUID library was used to create the document IDs for the .html files. Within the parsing function in the Crawler class, the response from the scrapy}$
# $\text{crawler would be written into each .html file, which is specified through the allowed max pages. Furthermore, a check was added to ensure any web pages}$
# $\text{that were crawled had the tag "/wiki/" within their link. This tag notifies the web crawler to only scrap wikipedia articles, avoiding an special web pages,}$
# $\text{categories, and files. After these checks are performed, the crawler uses the response.follow() function to follow the specified link. Sincce the Scrapy}$
# $\text{web crawler was designed in a jupyter notebook, it could not run by only calling crawl\_process.start() since it would cause a Runtime Exception. To counter}$
# $\text{this issue, a run\_crawler() fucntion was created to encapsulate the function calls CrawlerProcess(), crawl\_process.crawl(), and crawl\_process.start(). A}$
# $\text{thread was created to run the function run\_crawler with the Thread() function; this thread was started using the thread.start() function. The benefit}$
# $\text{of running the scrapy web crawler through a thread was to avoid any Runtime Exeptions and avoid the kernal from crashing due to being overloaded}$
# $\text{with running the cell and the Scrapy web crawler simultaneously.}$

# %% [markdown]
# $\text{To build the positional inverted index, the function used the "BeautifulSoup" library to extract terms the .html files. A text document was contructed}$
# $\text{for each .html file and the results where stored in a list, alongside their respective document IDs where the text was extracted  from. The library}$
# $\text{"re" was used to properly tokenize each term and ignores all punctuation. The inverted index is then built with the tokens, document IDs, and the positions}$
# $\text{ of each term in a given document. These results, stored in a list of tuples, are written into a .json file and formatted as the professor's example}$
# $\text{through custum string formatting. The search algorithm uses a helper function ("build text") that builds a proper corpus by extracting the directory with the .html}$
# $\text{files. After this extraction, the library "Beautiful Soup" is used to extract text from the .html files and connect them with their respective document IDs.}$
# $\text{Based on these results, its passed as an argument, alongside a query, to compute the TF IDF matrix and cosine similarity. Using Scikit learn,}$
# $\text{TfidfVectorizer and cosine similarity are imported to calculate each respective value. The library TfidfVectorizer is uses to remove any punctuation}$
# $\text{and to label the importance of each term in a document. These results are used to create the TF IDF matrix through the "fit transform" function. A query}$
# $\text{vector is created through the function "transform." Based on these calculation, the cosine similarity is calculated with the query vector and TF IDF matrix}$
# $\text{as arguments. The function then returns the document ID, consine similarity, and the TF IDF weights for the specified query terms. Within this implementation, the}$
# $\text{"build text" was necessary to build the corpus as the "fit transform" function only accepts raw text documents; this is the main reason why the positional inverted}$
# $\text{index is not used to create the TF IDF matrix.}$

# %% [markdown]
# $\text{A Flask processor function was created with a POST route with the top k and the queries.csv file being sent through the post() function. The queries.csv file}$
# $\text{goes through error checking pipeline to validate if a file was sent through the post() function. For the top k value, it is not required to be an argument for}$
# $\text{the post() function since a default value of 3 is set for top k ranked retrieval. When the file is successfully retrieved, the data within}$
# $\text{the csv file is extracted using pandas library, specifically through a dataframe for easier access. Once the csv file is extracted using pd.read-csv() function,}$
# $\text{the processor function iterates through the dataframe to extract query ID and query text. Once the extractions are successful, both fields are checked if they are}$
# $\text{valid (ensuring neither field is empty). Once this is completed, the search function is used to pass the query text and the corpus (created using build text() function).}$
# $\text{With the results from the search algorithm, a new csv file is created ("results.csv") that store the document ID, query text, and rank. Before writing }$
# $\text{the results into the results.csv, the results are ranked based on a specified top-k value. For the purposes of this report, the default top-k value of 3 was used. The ranked}$
# $\text{results are stored in a list ("out-df"), which is then converted into a dataframe using the pd.DataFrame() fucntion. To begin the writing process, a buffer is created}$
# $\text{to tell the to-csv() function to have the data be convereted into strings. The to-csv() function is used on the "out-df" dataframe and is returned}$
# $\text{as a csv by the processing function using send-file(). The processor function returns results.csv file with ranked retrieval of k = 3 and displayng the ranks}$
# $\text{between each document ID and query ID. In the final submission, the k value is set to 10 for top 10 ranked retrieval. Other error checking done throughout}$
# $\text{the procesor function was unexpected server errors, failure of the search() algorithm on a specific query id, and csv read errors. Since the}$
# $\text{development of the Flask processor was in a jupyter notebook, a thread was created to safely run the Flask application. When running the}$
# $\text{application without a thread, the cell never finished and kernel kept running until interrupted. Hence, creating a thread with threading.Thread() and}$
# $\text{thread.start() was the safest option for safe execution.}$

# %% [markdown]
# $\textbf{\underline{Operation}}$

# %% [markdown]
# $\text{To run the set up the environment, the following packages need to be installed:}$
#
# $\text{- Scrapy}$
#
# $\text{- Flask}$
#
# $\text{- Scikit Learn}$
#
# $\text{- BeautifulSoup}$
#
# $\text{The following commands can be done to install each package:}$
#
# $\text{- Scrapy: pip install Scrapy}$
#
# $\text{- Flask: pip install flask}$
#
# $\text{- Scikit Learn: pip install scikit-learn}$
#
# $\text{- BeautifulSoup: pip install beautifulsoup4}$
#
# $\text{Since the codebase is based in a jupyter notebook, no additional commands are needed to run the environment or the code.}$

# %% [markdown]
# $\text{The following inputs are given for each major part of the project:}$
#
# $\text{- Scrapy Web Crawler: (seed\_url = https://en.wikipedia.org/wiki/Main\_Page, max\_pages = 10, max\_depth = 1, save\_dir = "downloaded-pages")}$
#
# $\text{- Inverted Index Builder: ("downloaded\_pages", "index.json") ; The "index.json" input will be the name of the output json file }$
#
# $\text{- Build Text (corpus builder): ("downloaded\_pages")}$
#
# $\text{ - Search Algorithm: (query, corpus) ; corpus is retrieved from the build\_text() function}$
#
# $\text{- Flask Processor: (file = "queries.csv", data = "top-k" : 3)}$

# %% [markdown]
# $\textbf{\underline{Conclusion}}$

# %% [markdown]
# $\textbf{\underline{Data Sources}}$

# %% [markdown]
# $\textbf{\underline{Test Cases}}$

# %% [markdown]
# $\textbf{\underline{Source Code}}$

# %% [markdown]
# $\textbf{\underline{Bibliography}}$
